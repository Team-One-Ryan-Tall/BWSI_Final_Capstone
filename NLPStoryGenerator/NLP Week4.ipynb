# %%
import time
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from LanguageModel import LanguageModel
from ImageLoader import WordCaptionThing
from ImageLoader import load_image

# %%
wct = WordCaptionThing(10)
corpus = open("poems.txt", 'r').read() + open("Captions.txt", 'r').read()
model = LanguageModel(corpus, 11)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\bouen\Desktop\Projects\Programming\Python\BWSI\Week4\BWSI_Final_Capstone\NLPStoryGenerator\NLP Week4.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/bouen/Desktop/Projects/Programming/Python/BWSI/Week4/BWSI_Final_Capstone/NLPStoryGenerator/NLP%20Week4.ipynb#ch0000001?line=0'>1</a> wct = WordCaptionThing(10)
#       <a href='vscode-notebook-cell:/c%3A/Users/bouen/Desktop/Projects/Programming/Python/BWSI/Week4/BWSI_Final_Capstone/NLPStoryGenerator/NLP%20Week4.ipynb#ch0000001?line=1'>2</a> corpus = open("poems.txt", 'r').read() + open("Captions.txt", 'r').read()
#       <a href='vscode-notebook-cell:/c%3A/Users/bouen/Desktop/Projects/Programming/Python/BWSI/Week4/BWSI_Final_Capstone/NLPStoryGenerator/NLP%20Week4.ipynb#ch0000001?line=2'>3</a> model = LanguageModel(corpus, 11)
#
# ...

# %%
# from LanguageModel import LanguageModel
fig, ax = plt.subplots()
prompt = wct.get_random_prompt(model.n)
ax.imshow(load_image(prompt[0]))
print(model.generate_text(prompt[1], nletters=5000))
# Out:
# c:\Users\bouen\.conda\envs\week4\lib\site-packages\numpy\core\fromnumeric.py:86: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# hese dense clouds gravity pulls the gas in the past heic
#
# this new nasa esa hubble space telescopes and spacecraft the great mission to Mars,
# the individual threads making up such filaments also shows numerous finger like projections pointing up at the sky. She would have known this life was possible alien probe, and the Chicken lady. “We’ve got to get out. The Movement. How precious it is to be able to
# ...

# %%
# lm11.generate_text("Smoke arise")
# Out:
# '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'
